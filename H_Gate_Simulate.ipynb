# %% [markdown]
# # Introduction to Quantum Machine Learning
# # Building Your First Quantum Circuit
#
# We will be using IBM Qiskit libraries with IBM Quantum Simulation and a REAL IBM QUANTUM COMPUTER
#
# https://www.ibm.com/quantum-computing

# %% [markdown]
# ### This Notebook Built by Kinetic Labs

# %% [markdown]
# Import Libraries and set up IBM Qiskit

# %%
import numpy as np
from qiskit import *
from qiskit.providers.aer import QasmSimulator
from qiskit.visualization import plot_histogram

# %% [markdown]
# ### Building the circuit

# %% [markdown]
# Building a basic circit needed for your first program is the QuantumCircuit.  We begin by creating a `QuantumCircuit` comprised of 2 qubits.

# %%
circuit = QuantumCircuit(2, 2)

# %%
circuit.draw()
# Out:
#
# q_0:
#
# q_1:
#
# c: 2/

# %% [markdown]
# ### Adding Gates
# ### The Hadamard gate (H-gate) is a fundamental quantum gate.
# It allows us to move away from the poles of the Bloch sphere and create a superposition of |0⟩ | 0 ⟩ and |1⟩ | 1 ⟩. It has the matrix: We can see that this performs the transformations below:

# %% [markdown]
# We create the circuit with its registers, you can add gates ("operations") to manipulate the registers.below is an example of a quantum circuit that makes a two-qubit GHZ state
#
# $$|\psi\rangle = \left(|00\rangle+|11\rangle\right)/\sqrt{2}.$$

# %% [markdown]
# To create such a state, we start with a two-qubit quantum register. By default, each qubit is initialized to
# $|0\rangle$. To make the GHZ state, we apply the following gates:

# %% [markdown]
# ![Kinetic%20Data%20Quantum_h_gates.png](attachment:Kinetic%20Data%20Quantum_h_gates.png)

# %%
circuit.h(0)
circuit.draw(output="mpl")

# %% [markdown]
# ### Bellow is an illastration on how the Hadamard H-Gate Creates a superposition of |0⟩ | 0 ⟩ and |1⟩ | 1 ⟩ on the Qubit.
# This visulazation illastration can be found using the IBM composer at
# https://quantum-computing.ibm.com/composer

# %% [markdown]
# ![Kinetic%20Labs%20H%20Gate%2011.png](attachment:Kinetic%20Labs%20H%20Gate%2011.png)

# %% [markdown]
# ## Complete the Circuit <a name='visualize'></a>
#
# The below output of the complete circuit shows 2x QuBits q0 and q1 with the circuit.measure([0,1], [0,1]) so that the H-gate with the addition of a CNOT gate will allow quantum output from the QuBits to be translated to Classical Bits.

# %% [markdown]
# ![Kinetic%20Data%20Quantum_cnot_gates.png](attachment:Kinetic%20Data%20Quantum_cnot_gates.png)

# %%
# %matplotlib inline

# %%
circuit.cx(0,1) # 0-> # control qubit, 1-> target qubit
circuit.measure([0,1], [0,1])
circuit.draw(output="mpl")

# %% [markdown]
# ### Attaching the built Circuit to IBM Simulated Quantum Simulator

# %%
# List avalible IBM quantum simulation computers
Aer.backends()
# Out:
# [AerSimulator('aer_simulator'),
#  AerSimulator('aer_simulator_statevector'),
#  AerSimulator('aer_simulator_density_matrix'),
#  AerSimulator('aer_simulator_stabilizer'),
#  AerSimulator('aer_simulator_matrix_product_state'),
#  AerSimulator('aer_simulator_extended_stabilizer'),
#  AerSimulator('aer_simulator_unitary'),
#  AerSimulator('aer_simulator_superop'),
#  QasmSimulator('qasm_simulator'),
#  StatevectorSimulator('statevector_simulator'),
#  UnitarySimulator('unitary_simulator'),
#  PulseSimulator('pulse_simulator')]

# %%
# Build a simulator from IBM List of available simulators
simulator = Aer.get_backend("qasm_simulator")

# %%
result = execute(circuit,backend=simulator).result()

# %%
plot_histogram(result.get_counts(circuit))

# %% [markdown]
# ### Above we have even distobution |0⟩ | 0 ⟩ and |1⟩ | 1 ⟩

# %% [markdown]
# ![AdobeStock_335507784.jpeg](attachment:AdobeStock_335507784.jpeg)

# %% [markdown]
# ![Kinetic%20Data%20Logo.png](attachment:Kinetic%20Data%20Logo.png)
